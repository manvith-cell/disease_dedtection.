# %%
print("====diagnosis system activated====")

fever=input("do you have fever?(yes/no)")
cough=input("do you have cough?(yes/no)")
headach=input("do you have headach?(yes/no)")
fatigue=input("do you have fatigue?(yes/no)")
vommitting=input("do you have vommitting?(yes/no)")
chest_pain=input("do you have chest pain?(yes/no)")
breathing_difficulty=input("do you have breathing difficulty?(yes/no)")
body_pain=input("do you have body pain?(yes/no)")
excessive_thirst=input("do you have excessive thirst?(yes/no)")
frequent_urination=input("do you have frequent urination?(yes/no)")
sore_throat=input("do you have sore throat?(yes/no)")
shivering=input("do you have shivering?(yes/no)")
stomach_pain=input("do you have stomach pain?(yes/no)")
dizziness=input("do you have dizziness?(yes/no)")
chest_tightness=input("do you have chest tightness?(yes/no)")

print("===analysing symptoms===")
if cough=='yes' and sore_throat=='yes' and fever=='yes':
    print("you have common cold")
elif fever=='yes' and body_pain=='yes' and fatigue=='yes' and headach=='yes':
    print("you have Flu")
elif fever=='yes' and cough=='yes' and breathing_difficulty=='yes' and fatigue=='yes':
    print("you have COVID like infection")
elif vommitting=='yes' and stomach_pain=='yes' and fever=='yes':
    print("you have migrane")
elif chest_pain=='yes' and breathing_difficulty=='yes' and dizziness=='yes':
    print("you have heart disease risk")
elif excessive_thirst=='yes' and frequent_urination=='yes' and fatigue=='yes':
    print("you have diabetes risk")
elif fever=='yes' and body_pain=='yes' and headach=='yes'and vommitting=='yes':
    print("you have dengue like symptoms")
elif fever=='yes' and shivering=='yes' and  headach=='yes':
    print("you have malaria like symptoms")
elif stomach_pain=='yes' and vommitting=='yes':
    print("you have gastric problem")
elif breathing_difficulty=='yes' and cough=='yes' and chest_tightness=='yes':
    print("you have asthama")
elif dizziness=='yes' and fatigue=='yes' and excessive_thirst=='yes':
    print("you have dehydration")
else:
  print("idk go to the doctor dude!!")
# Out:
# ====diagnosis system activated====
# do you have fever?(yes/no)yes
# do you have cough?(yes/no)no
# do you have headach?(yes/no)yes
# do you have fatigue?(yes/no)no
# do you have vommitting?(yes/no)no
# do you have chest pain?(yes/no)no
# do you have breathing difficulty?(yes/no)no
# do you have body pain?(yes/no)no
# do you have excessive thirst?(yes/no)no
# do you have frequent urination?(yes/no)no
# do you have sore throat?(yes/no)no
# do you have shivering?(yes/no)yes
# do you have stomach pain?(yes/no)no
# do you have dizziness?(yes/no)no
# do you have chest tightness?(yes/no)no
# ===analysing symptoms===
# you have malaria like symptoms
